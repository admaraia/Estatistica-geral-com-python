# %% [markdown]
# # Estatística Geral

# %% [markdown]
# ## Testes de hipóteses

# %% [markdown]
# ### Hipósteses estatísticas
# Uma alegação sobre um parâmetro populacional é chamada de hipótese estatística.
# Para testar uma hipótese estatística, você deve estabelecer cuidadosamente um par de hipóteses – uma representa uma alegação e a outra, seu complemento. Quando uma dessas hipóteses é rejeitada, a outra deve ser aceita. Dessas duas hipóteses, aquela que contém uma afirmativa de igualdade é a hipótese nula. O complemento de uma hipótese nula é a hipótese alternativa.

# %% [markdown]
# #### Hipótese nula (denotada por H0):
# é uma hipótese estatística que contém uma afirmativa de igualdade e deve escrever como =, < ou >. Para uma média, temos as três formas possíveis para a hipótese nula:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Hipótese alternativa (denotada por Ha)
# é o complemento da hipótese nula. É uma afirmativa que deve ser verdadeira se H0 for falsa e contém uma afirmativa de desigualdade, tal como <, != ou >. Para uma média, a hipótese alternativa comporta apenas uma das três formas:
# ![image.png](attachment:image.png)

# %% [markdown]
# O quadro a seguir mostra a relação entre as afirmativas verbais possíveis sobre o parâmetro μ e as hipóteses nula e alternativa correspondentes. Afirmativas semelhantes podem ser feitas para outros parâmetros populacionais, tais como p (proporção), σ (desvio padrão) ou σ² (variância).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercício – Estabelecendo as hipóteses nulla e alterrnativa
# Estabeleça as hipóteses nula e alternativa:
# - a) Uma universidade alega que a proporção de seus alunos formados em quatro anos é de 82%.
#     R: H0: p = 0,82 vs. Ha: p != 0,82 - Hipótese bilateral
#
#
# - b) Um fabricante de torneiras alega que a taxa de fluxo médio de um determinado tipo de torneira é inferior a 2,5 galões por minuto.
#     H0: μ >= 2,5 vs. Ha: μ < 2,5 - Hipótese unilateral à esquerda
#
#
# - c) Um fabricante de pneus alega que a variância no diâmetro de um determinado modelo é de 8,6 polegadas.
#     H0: σ² = 8,6 vs. Ha: σ² != 8,6 - Hipótese bilateral
#
#
# - d) Uma companhia que fabrica cereais alega que o peso médio do conteúdo de suas caixas de cereais é de, no máximo, 200 gramas.
#     H0: μ <= 200 vs. Ha: μ > 200 - Hipótese unilateral à direita
#
#
# - e) Uma estação de rádio alega que sua proporção de audiência local é superior a 39%.
#     H0: p <= 0,39 vs. Ha: p > 0,39 - Hipótese unilateral à direita
#
#
# - f) Um restaurante alega que o desvio padrão para a duração do intervalo entre um atendimento e outro é inferior a 2,9 minutos.
#     H0: σ >= 2,9 vs. Ha: σ < 2,9 - Hipótese unilateral à esquerda

# %% [markdown]
# #### Tipos de erro de significância
# Não importando qual das hipóteses representa a alegação, você começará sempre um teste de hipóteses assumindo que a condição de igualdade na hipótese nula é verdadeira. Esse mesmo raciocínio é utilizado em processos criminais onde “Presume que o réu seja inocente até que sua culpa seja estabelecida sem sombra de dúvida”, a suposição de inocência é uma hipótese nula. Assim, quando realizar um teste de hipóteses, você deve tomar uma de duas decisões:
# - 1) Rejeitar a hipótese nula
# - 2) Aceitar a hipótese nula
#
# Uma vez que sua decisão baseia-se em informação incompleta (uma amostra em vez de toda a população), há sempre a possibilidade de se tomar a decisão errada. O quadro a seguir mostra os quatro resultados possíveis de um teste de hipóteses:
# ![image.png](attachment:image.png)

# %% [markdown]
# - Erro tipo I (denotada por α): Ocorre se a hipótese nula for rejeitada quando ela for realmente verdadeira.
# - Erro tipo II (denotada por β): Ocorre se a hipótese nula não for rejeitada quando ela for realmente falsa.

# %% [markdown]
# Uma das etapas de nosso processo de teste de hipóteses envolve a escolha do nível de significância (α), que é a probabilidade de um erro tipo I. Entretanto, não selecionamos β (a probabilidade de erro tipo II). Seria ótimo se pudéssemos ter sempre α=0 e β=0, mas isto não é possível; devemos, pois, procurar controlar as probabilidades de erro α e β. Pode-se mostrar, matematicamente, que α, β e o tamanho (n) da amostra estão todos inter relacionados, de forma que, escolhidos quaisquer dois deles, o terceiro está automaticamente determinado. Valem as seguintes considerações de ordem prática:

# %% [markdown]
# Uma das etapas de nosso processo de teste de hipóteses envolve a escolha do nível de significância (α), que é a probabilidade de um erro tipo I. Entretanto, não selecionamos β (a probabilidade de erro tipo II). Seria ótimo se pudéssemos ter sempre α=0 e β=0, mas isto não é possível; devemos, pois, procurar controlar as probabilidades de erro α e β. Pode-se mostrar, matematicamente, que α, β e o tamanho (n) da amostra estão todos inter relacionados, de forma que, escolhidos quaisquer dois deles, o terceiro está automaticamente determinado. Valem as seguintes considerações de ordem prática:
#
#
# - 1. Para α fixo, um aumento do tamanho n da amostra ocasiona uma redução de β; isto é, uma amostra maior reduz a chance de cometermos o erro de aceitar a hipótese nula quando ela é falsa.
# - 2. Para um tamanho n, fixo, de amostra, uma diminuição de α acarreta um aumento de β; reciprocamente, um aumento de α acarreta uma diminuição de β.
# - 3. Para reduzir α e β, devemos aumentar o tamanho da amostra.

# %% [markdown]
#     O nível de significância (α) de um teste é a probabilidade de uma hipótese nula ser rejeitada, quando verdadeira.

# %% [markdown]
# #### Estatística de teste, região crítica e valor crítico
# - A estatística de teste é uma estatística amostral, ou um valor baseado nos dados amostrais. Utiliza-se uma estatística de teste para tomar uma decisão sobre a rejeição ou não da hipótese nula.
# - A região crítica é o conjunto de todos os valores da estatística de teste que levam à rejeição da hipótese nula.
# - O valor crítico é o valor, ou valores, que separa(m) a região crítica dos valores da estatística de teste que não levam à rejeição da hipótese nula. Os valores críticos dependem da natureza da hipótese nula, da distribuição amostral principal, e do nível de significância (α).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Testes unilaterais e bilaterais (Região crítica)
# Nosso interesse em detectar desvios significativos de determinado parâmetro pode envolver desvios em ambas as direções ou apenas numa direção. Observe as situações a seguir que envolvem sucessivas jogadas de uma moeda:
#
# 1. A moeda pode ser considerada não equilibrada se aparece um número muito grande, ou muito pequeno, de caras. A hipótese alternativa seria simplesmente “a moeda não é equilibrada”, ou seja, Ha: p != 0,5, e investigaríamos então desvios em ambas a direções.
# 2. Se estivéssemos apostando em caras, então nossa preocupação seria somente com um número muito pequeno de caras. A hipótese alternativa seria “aparecem muito poucas caras”, isto é, Ha: p < 0,5, e só estaríamos interessados então nesse tipo de desvio do número esperado de caras.
#
# Essencialmente, a hipótese alternativa é usada para indicar qual aspecto nos interessa.
# Há três casos possíveis: concentrar em ambas as direções, concentrar nos desvios
# abaixo do valor esperado ou concentrar nos desvios acima do valor esperado. Esses três
# casos podem ser representados como a seguir, para o caso de uma proporção:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### O método clássico de teste de hipóteses (Utilizando a região crítica)
# - 1 - Identificar a hipótese nula (contém a condição de igualdade) e a hipótese alternativa (complementar).
#
# - 2 - Escolher o nível de significância com base na gravidade do erro tipo I. São muito comuns os valores 0,05 e 0,01.
#
# - 3 - Identificar o teste a ser utilizado.
#
# - 4 - Determinar a estatística de teste.
#
# - 5 - Determinar o(s) valor(es) crítico(s) e a região crítica.
#
# - 6 - Rejeitar H0 se a estatística de teste está na região crítica. Aceitar H 0 se a estatística de teste não está na região crítica.
#
# - 7 - Formular uma conclusão que descreva a conseqüência prática dos dados e dos cálculos.

# %% [markdown]
# #### O método clássico de teste de hipóteses (Utilizando a região crítica)
# - 1 - Identificar a hipótese nula (contém a condição de igualdade) e a hipótese alternativa (complementar).
#
# - 2 - Escolher o nível de significância com base na gravidade do erro tipo I. São muito comuns os valores 0,05 e 0,01.
#
# - 3 - Identificar o teste a ser utilizado.
#
# - 4 - Determinar a estatística de teste.
#
# - 5 - Determinar o(s) valor(es) crítico(s) e a região crítica.
#
# - 6 - Rejeitar H0 se a estatística de teste está na região crítica. Aceitar H 0 se a estatística de teste não está na região crítica.
#
# - 7 - Formular uma conclusão que descreva a conseqüência prática dos dados e dos cálculos.

# %% [markdown]
# ### Teste de hipóteses para uma média quando σ é conhecido (Teste z para uma amostra)
# O objetivo dos testes de hipóteses para uma média é avaliar afirmações feitas a
# respeito da média populacional. O teste de hipóteses descrito nesta seção será utilizado para uma média quando o desvio padrão populacional (σ) for conhecido.
#
# Identificadas as hipóteses estatísticas (H0 e Ha) e definido o nível de significância (α) podemos proceder ao cálculo da estatística de teste utilizando a fórmula a seguir:
# ![image.png](attachment:image.png)
# onde μ0 representa o valor da média que está sendo testado, σ representa o desvio padrão populacional, n é o tamanho da amostra e x̄ é a média da amostra.
#
# A região crítica para o teste z é construída levando-se em consideração a distribuição z, o nível de significância adotado no teste e a hipótese alternativa. Observe as figuras a seguir:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dessa forma, para o teste z para uma média, podemos estabelecer o seguinte critério de decisão:
# ![image.png](attachment:image.png)

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np


# Descrição das hipóteses:

H0 = "Média_<=_20"   #Hipótese nula (com igualdade)
Ha = "Média_>_20"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 50 #reclamações
Média_amostral = 29 #dias
Significância = 5 #% (alfa)
Desvio_populacional = True #O desvio conhecido é populacional?
Desvio_padrão = 21 #Valor do desvio padrão populacional ou amostral


#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100

#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")

#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Verificação da hipótese nula
if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
# Out:
# Alfa:  0.05
# Valor crítico:  1.64
# Valor estudado:  20.0
#
#
# Unilateral_esquerda:  False
# Bilateral:  False
# Unilaretal_direita:  True
#
#
# Estatística de teste:  3.0305
# H0 rejeitada pois, Estatística de teste 3.0305 >= Valor crítico 1.64

# %% [markdown]
# #### Exercício
# Suponha que queiramos avaliar a afirmação de um fabricante, de que seus pneus radiais suportam uma quilometragem de 40000 milhas, no mínimo. Para uma amostra aleatória de 49 pneus observou-se uma média de duração de 38000 milhas. Sabe-se que o desvio padrão populacional da duração dos pneus é de 3500 milhas. Utilize um nível de significância de 0,03. O que você pode concluir?
#
# R: H0: μ>4000 vs HA: μ<40000
# zteste= - 4
# z0,03= -1,88
# Como zteste< z0,03, deve-se rejeitar H0.
# Conclusão: A duração média dos pneus radiais é inferior a 40000 milhas, contradizendo a afirmação do fabricante a um nível de 3% de significância.

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np


# Descrição das hipóteses:

H0 = "Média_>=_40000"   #Hipótese nula (com igualdade)
Ha = "Média_<_40000"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 49 #pneus
Média_amostral = 38000 #milhas
Significância = 3 #% (alfa)
Desvio_populacional = True #O desvio conhecido é populacional?
Desvio_padrão = 3500 #Valor do desvio padrão populacional ou amostral


#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100

#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")

#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Verificação da hipótese nula
if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
# Out:
# Alfa:  0.03
# Valor crítico:  1.88
# Valor estudado:  40000.0
#
#
# Unilateral_esquerda:  True
# Bilateral:  False
# Unilateral_direita:  False
#
#
# Estatística de teste:  -4.0
# H0 rejeitada pois, Estatística de teste -4.0 <= Valor crítico -1.88

# %% [markdown]
# ### O método do valor p para o teste de hipóteses
# Muitos artigos profissionais e programas de computador utilizam outra abordagem do teste de hipóteses, baseada no cálculo do valor de uma probabilidade, ou valor p.
# Dada uma hipótese nula e um conjunto de dados amostrais, o valor p reflete a probabilidade de se obter tais resultados no caso da hipótese nula ser, de fato verdadeira, ou seja, quantifica o erro cometido ao rejeitar a hipótese nula. Um valor p muito pequeno sugere que os resultados amostrais são muito improváveis sob a hipótese nula, ou seja, constitui evidência contra a hipótese nula.
#
# O critério de decisão baseado no valor p é feito da seguinte maneira:
# - Rejeitar a hipótese nula (H0) se o valor p é no máximo igual ao nível de significância (α).
# - Não rejeitar a hipótese nula (H0) se o valor p é maior do que o nível de significância (α).
#
# O esquema a seguir mostra a determinação dos valores p.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função normal padrão e calculando a Probabilidade de z.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np


# Descrição das hipóteses:

H0 = "Média_<=_20"   #Hipótese nula (com igualdade)
Ha = "Média_>_20"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 50 #reclamações
Média_amostral = 29 #dias
Significância = 5 #% (alfa)
Desvio_populacional = True #O desvio conhecido é populacional?
Desvio_padrão = 21 #Valor do desvio padrão populacional ou amostral


#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf) * 2
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de o valor-cp:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeictada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceita, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
# Out:
# Alfa:  0.05
# Valor crítico:  1.64
# Valor estudado:  20.0
#
#
# Unilateral_esquerda:  False
# Bilateral:  False
# Unilateral_direita:  True
#
#
# Estatística de teste:  3.0305
# P valor:  0.001221
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 rejeitada pois, Estatística de teste 3.0305 >= Valor crítico 1.64
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 rejeitada, pois P-valor 0.001221 < Alfa 0.05

# %% [markdown]
# #### Exercício
# - 1 - Para o exercício anterior que mostra o caso da duração de pneus radiais, obtenha a conclusão utilizando o valor p.
#
#     R: H0: μ>=4000 vs HA: μ<40000
#     zteste= - 4
#     Valor p = 0,5-0,4998 = 0,0002
#     Como valor p < 0,03, deve-se rejeitar H0.
#     Conclusão: A duração média dos pneus radiais é inferior a 40000 milhas, contradizendo a afirmação do fabricante a um nível de 3% de significância.

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np


# Descrição das hipóteses:

H0 = "Média_>=_40000"   #Hipótese nula (com igualdade)
Ha = "Média_<_40000"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 49 #pneus
Média_amostral = 38000 #milhas
Significância = 3 #% (alfa)
Desvio_populacional = True #O desvio conhecido é populacional?
Desvio_padrão = 3500 #Valor do desvio padrão populacional ou amostral


#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf) * 2
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de o valor-cp:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceita, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
# Out:
# Alfa:  0.03
# Valor crítico:  1.88
# Valor estudado:  40000.0
#
#
# Unilateral_esquerda:  True
# Bilateral:  False
# Unilateral_direita:  False
#
#
# Estatística de teste:  -4.0
# P valor:  3.2e-05
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 rejeitada pois, Estatística de teste -4.0 <= Valor crítico -1.88
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 rejeictada, pois P-valor 3.2e-05 < Alfa 0.03

# %% [markdown]
# #### Exercício
# - 2 - Um representante de um grupo comunitário informa a um potencial construtor de um shopping, que a renda familiar média mensal nesta área é superior a RS6500. Suponha que, para o tipo de área envolvida, a renda familiar possa ser assumida como seguindo a distribuição normal, e que o desvio padrão pode ser aceito como sendo igual a σ = 2000, baseado em um estudo anterior. Para uma amostra aleatória de 55 residências, a renda familiar média encontrada é de RS6300. Verifique se há evidências que confirmem a hipótese do representante do grupo comunitário, considere um nível de 2% de significância. Utilize a região crítica e o valor p para concluir o teste.
#
#     R: H0: μ<=6500 vs HA: μ>6500
#     zteste= -0,7416
#     Valor p = 0,5+0,2704 = 0,7704
#     Como valor p > 0,02, NÃO deve-se rejeitar H0.
#     Conclusão: Conclui-se com 2% de significância que a renda familiar média mensal nesta área é de, no máximo, RS6500. Dessa forma, não há evidências que confirmem a hipótese do representante do grupo comunitário.

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np


# Descrição das hipóteses:

H0 = "Média_<=_6500"   #Hipótese nula (com igualdade)
Ha = "Média_>_6500"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 55 #residências
Média_amostral = 6300 #reais
Significância = 2 #% (alfa)
Desvio_populacional = True #O desvio conhecido é populacional?
Desvio_padrão = 2000 #Valor do desvio padrão populacional ou amostral


#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf) * 2
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de o valor-cp:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
# Out:
# Alfa:  0.02
# Valor crítico:  2.05
# Valor estudado:  6500.0
#
#
# Unilateral_esquerda:  False
# Bilateral:  False
# Unilateral_direita:  True
#
#
# Estatística de teste:  -0.7416
# P valor:  0.770835
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 aceitada pois, Estatística de teste -0.7416 < Valor crítico 2.05
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 aceitada, pois P-valor 0.770835 >= Alfa 0.02

# %% [markdown]
# ### Teste de hipóteses (z) com intervalos de confiança
# Já vimos anteriormente o método de estimação intervalar que consiste em encontrar uma estimativa intervalar de um parâmetro populacional que contém os valores prováveis daquele parâmetro. Por conseguinte, devemos rejeitar uma afirmação de que o parâmetro populacional tenha um valor que não está compreendido no intervalo de confiança.
#
# É importante lembrar que, como vimos o método de construção de intervalos de
# confiança bilaterais para um parâmetro, essa correspondência direta entre um
# intervalo de confiança e um teste de hipótese deve ser feita quando o teste é bilateral.

# %% [markdown]
# #### Exercício:
# - 1 - Um estudante de direito quer conferir a alegação de sua professora de que fraudadores condenados passam, em média 12,3 meses na cadeia. Uma amostra aleatória de 35 casos do arquivo judiciário indicou uma média de 11,5 meses. Suponha que o desvio padrão seja σ = 3,8 meses. Adote um nível de 4% de significância. O que o estudante pode concluir a partir dos dados da amostra? Utilize o valor p e o intervalo de confiança.
#
#     R: H0: μ=12,3 vs HA: μ≠12,3
#     zteste= -1,2455
#     Pelo método do Valor p:
#     Valor p = 2x(0,5-0,3944)=0,2112
#     Como valor p > 0,04, NÃO deve-se rejeitar H0.
#
#     Pelo método do intervalo de confiança (já que estamos em um teste bilateral):
#     z=2,05
#     E= 1,3167 meses
#     I.C.= [10,1833 meses ; 12,8167 meses]
#     Como o valor de μ0 = 12,3 está compreendido no intervalo de confiança, não deve-se rejeitar H0. Confirmando a conclusão obtida pelo método do valor p.
#
#     Conclusão: Conclui-se com 4% de significância que o tempo médio que fraudadores condenados passam na cadeia é de 12,3 meses. Dessa forma, há evidências que confirmam a alegação da professora.

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np




# Descrição das hipóteses:

H0 = "Média_=_12.3"   #Hipótese nula (com igualdade)
Ha = "Média_<>_12.3"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 35 #casos
Média_amostral = 11.5 #meses
Significância = 4 #% (alfa)
Desvio_populacional = True #O desvio conhecido é populacional?
Desvio_padrão = 3.8 #Valor do desvio padrão populacional ou amostral




#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
    P_valor = P_valor * 2
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_médias_amostrais = Desvio_padrão/(N_amostras**0.5)
        E = round(Valor_crítico * Desvio_médias_amostrais,4)
        if Valor_estudado > Média_amostral-E and Valor_estudado < Média_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
# Out:
# Alfa:  0.04
# Valor crítico:  2.05
# Valor estudado:  12.3
#
#
# Unilateral_esquerda:  False
# Bilateral:  True
# Unilateral_direita:  False
#
#
# Estatística de teste:  -1.2455
# P valor:  0.212948
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 aceitada pois, Valor crítico -2.05 < Estatística de teste -1.2455 < Valor crítico 2.05
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 aceitada, pois P-valor 0.212948 >= Alfa 0.04
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# H0 aceitada, pois o Valor estudado 12.3 está contido no intervalo de confiança I.C = [11.5-1.3168 ; 11.5+1.3168] ou seja, de 10.1832 a 12.8168

# %% [markdown]
# ### Teste de hipóteses para uma média quando σ é desconhecido (Teste t-Student para uma amostra)
# O teste t-Student, assim como o teste z (visto anteriormente), é um teste de hipóteses para a média. Ele será utilizado quando σ é desconhecido e a população original tem distribuição essencialmente normal.
# Quando o desvio padrão da população não é conhecido (que é o caso no teste t-
# Student), usa-se o desvio padrão da amostra como estimativa, substituindo σ por s nas fórmulas. Isto não acarreta maiores dificuldades, pois o desvio padrão amostral dá uma aproximação bastante razoável do verdadeiro valor, na maioria dos casos.
#
# Além disso, pelo Teorema do Limite Central, sabemos que, quando o tamanho da amostra é superior ou igual a 30, a distribuição das médias é aproximadamente normal. Todavia, para amostras de menos de 30 observações, a aproximação normal não é adequada. Devemos então usar a distribuição t-Student, que é a distribuição correta quando se usa s.
#
# Após a identificação do teste a ser utilizado, procedemos com a definição das
# hipóteses estatísticas (H0 e Ha) e do nível de significância (α). A partir daí encontramos a estatística de teste:
# ![image.png](attachment:image.png)
# onde μ0 representa o valor da média que está sendo testado, s representa o desvio padrão da amostra (já que o desvio padrão da população é desconhecido), n é o tamanho da amostra e x̄ é a média da amostra.

# %% [markdown]
# A região crítica para o teste t-Student é definida da mesma forma que no teste z, ou seja, levando-se em consideração a distribuição t-Student, o nível de significância adotado no teste e a hipótese alternativa.
# O valor crítico é obtido na tabela t-Student onde:
# - Graus de liberdade (g.l.) = n – 1.
#
# Após determinar o número de graus de liberdade (na linha da tabela) e localizar, na coluna, o valor correspondente à área da cauda que se deseja obter, o valor crítico será o valor que corresponde ao cruzamento da linha e da coluna que foram determinados. Lembrando que se um valor crítico está localizado na cauda esquerda, devemos considerá-lo negativo.

# %% [markdown]
# #### Exemplo:
# A associação dos proprietários de indústrias metalúrgicas está muito preocupada com o tempo perdido com acidentes de trabalho, cuja média, nos últimos tempos tem sido da ordem de 60 horas/homem por ano. Tentou-se um programa de prevenção de acidentes, após o qual foi tomada uma amostra de nove indústrias e medido o número de horas/homens perdidas por acidente obtendo-se uma média de 50 horas e um desvio padrão de 20 horas. Você diria, considerando-se um nível de significância de 5%, que houve alguma alteração no tempo perdido com acidentes de trabalho? Suponha que a população segue aproximadamente a distribuição normal.
#
# Neste exemplo não há qualquer informação sobre o desvio padrão populacional e, além disso, supõe-se que a população tem distribuição aproximadamente normal. Portanto, temos que prosseguir com o teste utilizando a distribuição t-Student:
#
# Hipóteses: H0: μ = 60 versus Ha: μ ≠ 60.
#
# Nível de significância: α = 0,05.
#
# Graus de liberdade: n – 1 = 9 –1 = 8.
#
# Estatística de teste:
# ![image.png](attachment:image.png)

# %% [markdown]
# Reagião crítica:
# ![image.png](attachment:image.png)

# %% [markdown]
# Valor crítico: t = 2.306
# ![image.png](attachment:image.png)

# %% [markdown]
# Podemos observar que a estatística de teste (tteste = -1,5) está dentro do intervalo de -2,306 a 2,306, ou seja, concluímos por não rejeitar H0. Dessa forma, podemos dizer que não há evidências de que tenha havido alteração no tempo médio perdido com acidentes de trabalho em indústrias metalúrgicas.

# %% [markdown]
# Se optássemos por resolver esse exemplo usando o valor p teríamos que utilizar as mesmas idéias do teste z (que já foram demonstradas), ou seja, como estamos
# solucionando um teste bilateral, o valor p é dado por:
# ![image.png](attachment:image.png)

# %% [markdown]
# Dessa forma temos que localizar na tabela t-Student o Valor p = 2x P(t > Estatística de teste), ou seja, na linha correspondente ao número de graus de liberdade (n – 1 = 8) devemos localizar o valor mais próximo da estatística de teste (Tteste=1,5, considerando-se o valor positivo), observe a seguir:
# ![image.png](attachment:image.png)

# %% [markdown]
# O valor 0,1 encontrado corresponde à área acima da estatística de teste positiva, dessa forma, o valor p = 2 x 0,1 = 0,2, ou seja, se rejeitarmos a hipótese nula estamos cometendo um erro de 0,2 = 20%, como o erro máximo permitido é de α = 0,05 = 5%, devemos portanto aceitar a hipótese nula. Concluímos que o tempo médio perdido com acidentes de trabalho é igual a 60 horas/homem, não havendo indícios suficientes para concluirmos que houve alteração.

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Média_=_60"   #Hipótese nula (com igualdade)
Ha = "Média_<>_60"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 9 #casos
Média_amostral = 50 #meses
Significância = 5 #% (alfa)
Desvio_populacional = False #O desvio conhecido é populacional?
Desvio_padrão = 20 #Valor do desvio padrão populacional ou amostral




#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional and N_amostras >= 30:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))

    
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Desvio_populacional and N_amostras >= 30: # usando Z
    if Unilateral_esquerda:
        P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")
else: # usando T-Student
    if Unilateral_esquerda:
        P_valor, _ = quad(t.pdf, -np.inf, Estat_teste, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(t.pdf, Estat_teste, np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(t.pdf, abs(Estat_teste), np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_médias_amostrais = Desvio_padrão/(N_amostras**0.5)
        E = round(Valor_crítico * Desvio_médias_amostrais,4)
        if Valor_estudado > Média_amostral-E and Valor_estudado < Média_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
# Out:
# Alfa:  0.05
# Valor crítico:  2.306
# Valor estudado:  60.0
#
#
# Unilateral_esquerda:  False
# Bilateral:  True
# Unilateral_direita:  False
#
#
# Estatística de teste:  -1.5
# P valor:  0.172004
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 aceitada pois, Valor crítico -2.306 < Estatística de teste -1.5 < Valor crítico 2.306
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 aceitada, pois P-valor 0.172004 >= Alfa 0.05
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# H0 aceitada, pois o Valor estudado 60.0 está contido no intervalo de confiança I.C = [50-15.3733 ; 50+15.3733] ou seja, de 34.6267 a 65.3733

# %% [markdown]
# ### Exercícios definitivos de teste de hipóteses para a Média

# %% [markdown]
# 1. Um escritório de investimentos acredita que o rendimento médio das diversas ações que movimenta é de 20%. Uma nova estratégia foi definida com o objetivo de aumentar o rendimento médio das diversas ações que movimenta. Para verificar esta hipótese, tomaram-se 18 empresas ao acaso obtendo-se um rendimento médio de 24,56% e um desvio padrão de 5%. Suponha que a população tenha distribuição aproximadamente normal. Faça o teste estatístico para comprovar que a nova estratégia é realmente eficiente para aumentar o rendimento médio das diversas ações. Use um nível de significância de 1%.
#
#     R: Hipótese unilateral à direita, tteste=3,8692, valor p=0,0005

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Média_<=_20"   #Hipótese nula (com igualdade)
Ha = "Média_>_20"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 18 #casos
Média_amostral = 24.56 #%
Significância = 1 #% (alfa)
Desvio_populacional = False #O desvio conhecido é populacional?
Desvio_padrão = 5 #Valor do desvio padrão populacional ou amostral




#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional and N_amostras >= 30:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Desvio_populacional and N_amostras >= 30: # usando Z
    if Unilateral_esquerda:
        P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")
else: # usando T-Student
    if Unilateral_esquerda:
        P_valor, _ = quad(t.pdf, -np.inf, Estat_teste, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(t.pdf, Estat_teste, np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(t.pdf, abs(Estat_teste), np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_médias_amostrais = Desvio_padrão/(N_amostras**0.5)
        E = round(Valor_crítico * Desvio_médias_amostrais,4)
        if Valor_estudado > Média_amostral-E and Valor_estudado < Média_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# H0:  Média_<=_20
# Ha:  Média_>_20
#
#
# Alfa:  0.01
# Valor crítico:  2.567
# Valor estudado:  20.0
#
#
# Unilateral_esquerda:  False
# Bilateral:  False
# Unilateral_direita:  True
#
#
# Estatística de teste:  3.8693
# P valor:  0.000616
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 rejeitada pois, Estatística de teste 3.8693 >= Valor crítico 2.567
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 rejeitada, pois P-valor 0.000616 < Alfa 0.01
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.

# %% [markdown]
# 2. Uma amostra aleatória de oito pedidos dos arquivos de uma companhia mostra que os pedidos de certa peça de uma máquina forma despachados em: 12 10 17 14 13 18 11 9 dias. Ao nível de 5% de significância , podemos concluir que, em média, tais pedidos são despachados em menos de 10 dias?
#
#     R: Hipótese unilateral à esquerda, média da amostra=13, variância da amostra=10,2857, desvio padrão da amostra=3,2071, tteste=2,6458, valor p=1-0,0125=0,9875.

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Média_>=_10"   #Hipótese nula (com igualdade)
Ha = "Média_<_10"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

dados = [10, 17, 14, 13, 18, 11, 9]

N_amostras = len(dados) #amostras
Média_amostral = np.mean(dados) #dias
Significância = 5 #% (alfa)
Desvio_populacional = False #O desvio conhecido é populacional?
Desvio_padrão = np.std(dados) #Valor do desvio padrão populacional ou amostral




#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional and N_amostras >= 30:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Desvio_populacional and N_amostras >= 30: # usando Z
    if Unilateral_esquerda:
        P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")
else: # usando T-Student
    if Unilateral_esquerda:
        P_valor, _ = quad(t.pdf, -np.inf, Estat_teste, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(t.pdf, Estat_teste, np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(t.pdf, abs(Estat_teste), np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_médias_amostrais = Desvio_padrão/(N_amostras**0.5)
        E = round(Valor_crítico * Desvio_médias_amostrais,4)
        if Valor_estudado > Média_amostral-E and Valor_estudado < Média_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# H0:  Média_>=_10
# Ha:  Média_<_10
#
#
# Alfa:  0.05
# Valor crítico:  1.9432
# Valor estudado:  10.0
#
#
# Unilateral_esquerda:  True
# Bilateral:  False
# Unilateral_direita:  False
#
#
# Estatística de teste:  2.6136
# P valor:  0.980036
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 aceitada pois, Estatística de teste 2.6136 > Valor crítico -1.9432
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 aceitada, pois P-valor 0.980036 >= Alfa 0.05
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.

# %% [markdown]
# ### Teste de hipóteses para uma proporção
# Os testes de hipóteses para proporções são adequados quando os dados sob análise consistem de contagens ou frequências de itens. A finalidade de tais testes é avaliar afirmações sobre a proporção (ou percentagem) de uma população. As suposições associadas ao teste de hipóteses para uma proporção são descritas a seguir:
# - Devem ser verificadas as condições para um experimento binomial. Isto é, temos um número fixo de provas independentes com probabilidade constante, e cada prova comporta dois resultados, que são designados como “sucesso” e “fracasso”.
# - As condições n.p0 >= 5 e n.(1-p0) >= 5 são ambas verificadas, de modo que a distribuição binomial das proporções amostrais pode ser aproximada por uma distribuição normal com ![image.png](attachment:image.png)

# %% [markdown]
# Se as duas suposições acima forem satisfeitas podemos realizar o teste de hipóteses para uma proporção utilizando a tabela da distribuição normal padrão.
# A notação que utilizaremos é a seguinte:
#
#     n = tamanho da amostra;
#     p̂ = x/n = proporção amostral;
#     p0 = proporção populacional (usada nas hipóteses);
# A estatística de teste que será utilizada é obtida por:
# ![image.png](attachment:image.png)

# %% [markdown]
# Em muitos aspectos, o teste de hipóteses para uma proporção se assemelha
# grandemente ao teste z, principalmente pelo fato de que utilizam a mesma distribuição de probabilidades. Dessa forma, a região crítica, o valor crítico e o valor p para o teste de proporção são obtidos exatamente da mesma maneira que o teste z para uma média.

# %% [markdown]
# #### Exemplo:
# “Em um estudo da eficácia do air-bag em automóveis, constatou-se que, em 821 colisões de carros de tamanho médio equipados com air-bag, 46 colisões resultaram em hospitalização do motorista. Ao nível de significância de 0,01, teste a afirmação de que a taxa de hospitalização dos motoristas, nos casos de carros equipados com airbag, é inferior à taxa de 7,8% para colisões de carros de tamanho médio equipados com cintos automáticos de segurança.”

# %% [markdown]
# Podemos observar que a proporção amostral é de p̂ = 46/821 = 0.056, e a proporção populacional admitida é de 7,8% (0,078). O nível de significância a ser adotado é de 0,01 e as hipóteses podem ser definidas da seguinte maneira:
#
# H0: p >= 0,078
# Ha: p < 0,078
#
# Podemos verificar que as exigências do teste são ambas satisfeitas:
#
#     n.p0 >= 5 -> 821 x 0,078 = 64,04
#     n.(1-p0) >= 5 -> 821 x (1–0,078) = 756,96
#
# A estatística de teste é:
# ![image.png](attachment:image.png)

# %% [markdown]
# Região crítica:
# ![image.png](attachment:image.png)
# O valor crítico deverá ser o valor de z na tabela da distribuição normal que
# corresponde a uma área de 0,49, ou seja, z = 2,33. Como a estatística de teste (-2,35) é menor do que o valor crítico (-2,33) devemos rejeitar a hipótese nula.

# %% [markdown]
# Valor p:
# ![image.png](attachment:image.png)
# O valor p será a área da distribuição normal padrão abaixo da estatística de teste (-2,35), ou seja, 0,5 – 0,4906 = 0,0094. Interpretando o valor p temos que: Se rejeitarmos H0, ou seja, se afirmarmos que a taxa de hospitalização nos casos com airbag é inferior a 7,8% estamos cometendo um erro de 0,0094. Como o valor p (0,0094) é menor do que o nível de significância (0,01) vamos rejeitar H0.

# %% [markdown]
# Concluindo: Há indícios suficientes para garantir que a taxa de hospitalização nos casos de automóveis equipados com air-bag é inferior à taxa de 7,8%.

# %% [markdown]
# Vale a pena lembrar que, para testes bilaterais, existe a opção de conclusão por meio do intervalo de confiança já conhecido:
# ![image.png](attachment:image.png)
# Devemos rejeitar uma afirmação de que o parâmetro populacional tenha um valor que não está compreendido no intervalo de confiança.

# %% [markdown]
# Resolvendo o exemplo:

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Proporção.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Proporção_>=_0.078"   #Hipótese nula (com igualdade)
Ha = "Proporção_<_0.078"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 821 #colisões
Ocorrências = 46 #colisões
Prop_amostral = Ocorrências/N_amostras #proporção
Significância = 1 #% (alfa)



#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100

#Verificação das suposições para a Proporção
if (N_amostras * Valor_estudado >= 5) and (N_amostras * (1-Valor_estudado) >= 5):
    print ("Suposições satifeitas (OK) para aproximação da distribuição por uma normal.")
    print("\n")
else:
    print ("Suposições não satifeitas (NOK) para aproximação da distribuição por uma normal.")
    print("\n")

#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Prop_amostral-Valor_estudado)/(((Valor_estudado*(1-Valor_estudado))/N_amostras)**0.5),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
    P_valor = round(P_valor, 6)
    P_valor = P_valor * 2
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")



#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_prop_amostrais = ((Prop_amostral * (1-Prop_amostral))/N_amostras)**0.5
        E = round(Valor_crítico * Desvio_prop_amostrais,4)
        if Valor_estudado > Prop_amostral-E and Valor_estudado < Prop_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# Suposições satifeitas (OK) para aproximação da distribuição por uma normal.
#
#
# H0:  Proporção_>=_0.078
# Ha:  Proporção_<_0.078
#
#
# Alfa:  0.01
# Valor crítico:  2.33
# Valor estudado:  0.078
#
#
# Unilateral_esquerda:  True
# Bilateral:  False
# Unilateral_direita:  False
#
#
# Estatística de teste:  -2.3475
# P valor:  0.00945
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 rejeitada pois, Estatística de teste -2.3475 <= Valor crítico -2.33
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 rejeitada, pois P-valor 0.00945 < Alfa 0.01
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.

# %% [markdown]
# ### Exercícios definitivos de teste de hipóteses para a Proporção

# %% [markdown]
# 1. Um sistema de reservas da companhia Y acusa uma taxa de 7% de não comparecimento. Adotou-se então um novo processo, pelo qual as reservas são confirmadas no dia anterior ao do vôo, fazendo-se um estudo de 5218 reservas pelo novo sistema, selecionadas aleatoriamente. Se se registraram 333 não comparecimentos, teste a afirmação de que a taxa de não-comparecimento é menor no novo sistema. O novo sistema se afigura eficiente na redução do nãocomparecimento? Utilize um nível de 2% de significância.
#
#     R: Hipótese unilateral à esquerda
#     p̂ =0,0638
#     zteste= -1,7553
#     valor p = 0,5-0,4608 = 0,0392 > α -> NÃO rejeito a hipótese nula

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Proporção.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Proporção_>=_0.07"   #Hipótese nula (com igualdade)
Ha = "Proporção_<_0.07"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 5218 #reservas
Ocorrências = 333 #faltas
Prop_amostral = Ocorrências/N_amostras #proporção
Significância = 2 #% (alfa)



#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100

#Verificação das suposições para a Proporção
if (N_amostras * Valor_estudado >= 5) and (N_amostras * (1-Valor_estudado) >= 5):
    print ("Suposições satifeitas (OK) para aproximação da distribuição por uma normal.")
    print("\n")
else:
    print ("Suposições não satifeitas (NOK) para aproximação da distribuição por uma normal.")
    print("\n")

#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Prop_amostral-Valor_estudado)/(((Valor_estudado*(1-Valor_estudado))/N_amostras)**0.5),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
    P_valor = round(P_valor, 6)
    P_valor = P_valor * 2
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")



#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_prop_amostrais = ((Prop_amostral * (1-Prop_amostral))/N_amostras)**0.5
        E = round(Valor_crítico * Desvio_prop_amostrais,4)
        if Valor_estudado > Prop_amostral-E and Valor_estudado < Prop_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# Suposições satifeitas (OK) para aproximação da distribuição por uma normal.
#
#
# H0:  Proporção_>=_0.07
# Ha:  Proporção_<_0.07
#
#
# Alfa:  0.02
# Valor crítico:  2.05
# Valor estudado:  0.07
#
#
# Unilateral_esquerda:  True
# Bilateral:  False
# Unilateral_direita:  False
#
#
# Estatística de teste:  -1.7503
# P valor:  0.040033
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 aceitada pois, Estatística de teste -1.7503 > Valor crítico -2.05
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 aceitada, pois P-valor 0.040033 >= Alfa 0.02
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.

# %% [markdown]
# 2. Em um estudo de 71 fumantes que estavam procurando deixar de fumar utilizando uma terapia especial, 32 não estavam fumando um ano após o tratamento. Ao nível de 0,10 de significância, teste a afirmação de que, dos fumantes que procuram deixar de fumar com aquela terapia, no máximo 25% voltam a fumar um ano após o tratamento. Esses resultados sugerem que a terapia não é eficaz?
#
#     R: Hipótese unilateral à direita
#     p̂ =0,5493
#     zteste= 5,8242
#     valor p = 0,5-0,4998 = 0,0002 < α -> Rejeito a hipótese nula

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Proporção.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Proporção_<=_0.25"   #Hipótese nula (com igualdade)
Ha = "Proporção_>_0.25"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 71 #fumantes
Ocorrências = (71-32) #não fumaram
Prop_amostral = Ocorrências/N_amostras #proporção
Significância = 10 #% (alfa)



#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100

#Verificação das suposições para a Proporção
if (N_amostras * Valor_estudado >= 5) and (N_amostras * (1-Valor_estudado) >= 5):
    print ("Suposições satifeitas (OK) para aproximação da distribuição por uma normal.")
    print("\n")
else:
    print ("Suposições não satifeitas (NOK) para aproximação da distribuição por uma normal.")
    print("\n")

#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Prop_amostral-Valor_estudado)/(((Valor_estudado*(1-Valor_estudado))/N_amostras)**0.5),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
    P_valor = round(P_valor, 6)
    P_valor = P_valor * 2
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")



#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_prop_amostrais = ((Prop_amostral * (1-Prop_amostral))/N_amostras)**0.5
        E = round(Valor_crítico * Desvio_prop_amostrais,4)
        if Valor_estudado > Prop_amostral-E and Valor_estudado < Prop_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# Suposições satifeitas (OK) para aproximação da distribuição por uma normal.
#
#
# H0:  Proporção_<=_0.25
# Ha:  Proporção_>_0.25
#
#
# Alfa:  0.1
# Valor crítico:  1.28
# Valor estudado:  0.25
#
#
# Unilateral_esquerda:  False
# Bilateral:  False
# Unilateral_direita:  True
#
#
# Estatística de teste:  5.8241
# P valor:  0.0
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 rejeitada pois, Estatística de teste 5.8241 >= Valor crítico 1.28
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 rejeitada, pois P-valor 0.0 < Alfa 0.1
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.

# %%
#Declarando a tabela Z e tabela T-student

t_table = [
[None,0.25,0.125,0.1,0.05,0.025,0.0125,0.01,0.005,0.0025,0.001,0.0005		],
[1,1,2.414,3.078,6.314,12.71,25.45,31.82,63.66,127.3,318.3,636.6            ],
[2,0.817,1.604,1.8856,2.92,4.303,6.205,6.965,9.925,14.09,22.33,31.6         ],
[3,0.765,1.423,1.6377,2.3534,3.182,4.177,4.541,5.841,7.453,10.21,12.92      ],
[4,0.741,1.344,1.5332,2.1319,2.776,3.495,3.747,4.604,5.598,7.173,8.61       ],
[5,0.727,1.301,1.4759,2.0151,2.571,3.163,3.365,4.032,4.773,5.893,6.869      ],
[6,0.718,1.273,1.4398,1.9432,2.447,2.969,3.143,3.707,4.317,5.208,5.959      ],
[7,0.711,1.254,1.4149,1.8946,2.365,2.841,2.998,3.499,4.029,4.785,5.408      ],
[8,0.706,1.24,1.3968,1.8596,2.306,2.752,2.896,3.355,3.833,4.501,5.041       ],
[9,0.703,1.23,1.383,1.8331,2.262,2.685,2.821,3.25,3.69,4.297,4.781          ],
[10,0.7,1.221,1.3722,1.8125,2.228,2.634,2.764,3.169,3.581,4.144,4.587       ],
[11,0.697,1.214,1.3634,1.7959,2.201,2.593,2.718,3.106,3.497,4.025,4.437     ],
[12,0.695,1.209,1.3562,1.7823,2.179,2.56,2.681,3.055,3.428,3.93,4.318       ],
[13,0.694,1.204,1.3502,1.7709,2.16,2.533,2.65,3.012,3.372,3.852,4.221       ],
[14,0.692,1.2,1.345,1.7613,2.145,2.51,2.625,2.977,3.326,3.787,4.14          ],
[15,0.691,1.197,1.3406,1.7531,2.131,2.49,2.602,2.947,3.286,3.733,4.073      ],
[16,0.69,1.194,1.3368,1.7459,2.12,2.473,2.583,2.921,3.252,3.686,4.015       ],
[17,0.689,1.191,1.3334,1.7396,2.11,2.458,2.567,2.898,3.222,3.646,3.965      ],
[18,0.688,1.189,1.3304,1.7341,2.101,2.445,2.552,2.878,3.197,3.611,3.922     ],
[19,0.688,1.187,1.3277,1.7291,2.093,2.433,2.539,2.861,3.174,3.579,3.883     ],
[20,0.687,1.185,1.3253,1.7247,2.086,2.423,2.528,2.845,3.153,3.552,3.85      ],
[21,0.686,1.183,1.3232,1.7208,2.08,2.414,2.518,2.831,3.135,3.527,3.819      ],
[22,0.686,1.182,1.3212,1.7172,2.074,2.405,2.508,2.819,3.119,3.505,3.792     ],
[23,0.685,1.18,1.3195,1.7139,2.069,2.398,2.5,2.807,3.104,3.485,3.768        ],
[24,0.685,1.179,1.3178,1.7109,2.064,2.391,2.492,2.797,3.091,3.467,3.745     ],
[25,0.684,1.178,1.3164,1.7081,2.06,2.385,2.485,2.787,3.078,3.45,3.725       ],
[26,0.684,1.177,1.315,1.7056,2.056,2.379,2.479,2.779,3.067,3.435,3.707      ],
[27,0.684,1.176,1.3137,1.7033,2.052,2.373,2.473,2.771,3.057,3.421,3.69      ],
[28,0.683,1.175,1.3125,1.7011,2.048,2.368,2.467,2.763,3.047,3.408,3.674     ],
[29,0.683,1.174,1.3114,1.6991,2.045,2.364,2.462,2.756,3.038,3.396,3.659     ],
[30,0.683,1.173,1.3104,1.6973,2.042,2.36,2.457,2.75,3.03,3.385,3.646        ],
[31,0.682,1.172,1.3095,1.6955,2.04,2.356,2.453,2.744,3.022,3.375,3.633      ],
[32,0.682,1.172,1.3086,1.6939,2.037,2.352,2.449,2.738,3.015,3.365,3.622     ],
[33,0.682,1.171,1.3077,1.6924,2.035,2.348,2.445,2.733,3.008,3.356,3.611     ],
[34,0.682,1.17,1.307,1.6909,2.032,2.345,2.441,2.728,3.002,3.348,3.601       ],
[35,0.682,1.17,1.3062,1.6896,2.03,2.342,2.438,2.724,2.996,3.34,3.591        ]]

z_table = [
[0.0000,	0.0040,	0.0080,	0.0120,	0.0160,	0.0199,	0.0239,	0.0279,	0.0319,	0.0359],
[0.0398,	0.0438,	0.0478,	0.0517,	0.0557,	0.0596,	0.0636,	0.0675,	0.0714,	0.0753],
[0.0793,	0.0832,	0.0871,	0.0910,	0.0948,	0.0987,	0.1026,	0.1064,	0.1103,	0.1141],
[0.1179,	0.1217,	0.1255,	0.1293,	0.1331,	0.1368,	0.1406,	0.1443,	0.1480,	0.1517],
[0.1554,	0.1591,	0.1628,	0.1664,	0.1700,	0.1736,	0.1772,	0.1808,	0.1844,	0.1879],
[0.1915,	0.1950,	0.1985,	0.2019,	0.2054,	0.2088,	0.2123,	0.2157,	0.2190,	0.2224],
[0.2257,	0.2291,	0.2324,	0.2357,	0.2389,	0.2422,	0.2454,	0.2486,	0.2517,	0.2549],
[0.2580,	0.2611,	0.2642,	0.2673,	0.2704,	0.2734,	0.2764,	0.2794,	0.2823,	0.2852],
[0.2881,	0.2910,	0.2939,	0.2967,	0.2995,	0.3023,	0.3051,	0.3078,	0.3106,	0.3133],
[0.3159,	0.3186,	0.3212,	0.3238,	0.3264,	0.3289,	0.3315,	0.3340,	0.3365,	0.3389],
[0.3413,	0.3438,	0.3461,	0.3485,	0.3508,	0.3531,	0.3554,	0.3577,	0.3599,	0.3621],
[0.3643,	0.3665,	0.3686,	0.3708,	0.3729,	0.3749,	0.3770,	0.3790,	0.3810,	0.3830],
[0.3849,	0.3869,	0.3888,	0.3907,	0.3925,	0.3944,	0.3962,	0.3980,	0.3997,	0.4015],
[0.4032,	0.4049,	0.4066,	0.4082,	0.4099,	0.4115,	0.4131,	0.4147,	0.4162,	0.4177],
[0.4192,	0.4207,	0.4222,	0.4236,	0.4251,	0.4265,	0.4279,	0.4292,	0.4306,	0.4319],
[0.4332,	0.4345,	0.4357,	0.4370,	0.4382,	0.4394,	0.4406,	0.4418,	0.4429,	0.4441],
[0.4452,	0.4463,	0.4474,	0.4484,	0.4495,	0.4505,	0.4515,	0.4525,	0.4535,	0.4545],
[0.4554,	0.4564,	0.4573,	0.4582,	0.4591,	0.4599,	0.4608,	0.4616,	0.4625,	0.4633],
[0.4641,	0.4649,	0.4656,	0.4664,	0.4671,	0.4678,	0.4686,	0.4693,	0.4699,	0.4706],
[0.4713,	0.4719,	0.4726,	0.4732,	0.4738,	0.4744,	0.4750,	0.4756,	0.4761,	0.4767],
[0.4772,	0.4778,	0.4783,	0.4788,	0.4793,	0.4798,	0.4803,	0.4808,	0.4812,	0.4817],
[0.4821,	0.4826,	0.4830,	0.4834,	0.4838,	0.4842,	0.4846,	0.4850,	0.4854,	0.4857],
[0.4861,	0.4864,	0.4868,	0.4871,	0.4875,	0.4878,	0.4881,	0.4884,	0.4887,	0.4890],
[0.4893,	0.4896,	0.4898,	0.4901,	0.4904,	0.4906,	0.4909,	0.4911,	0.4913,	0.4916],
[0.4918,	0.4920,	0.4922,	0.4925,	0.4927,	0.4929,	0.4931,	0.4932,	0.4934,	0.4936],
[0.4938,	0.4940,	0.4941,	0.4943,	0.4945,	0.4946,	0.4948,	0.4949,	0.4951,	0.4952],
[0.4953,	0.4955,	0.4956,	0.4957,	0.4959,	0.4960,	0.4961,	0.4962,	0.4963,	0.4964],
[0.4965,	0.4966,	0.4967,	0.4968,	0.4969,	0.4970,	0.4971,	0.4972,	0.4973,	0.4974],
[0.4974,	0.4975,	0.4976,	0.4977,	0.4977,	0.4978,	0.4979,	0.4979,	0.4980,	0.4981],
[0.4981,	0.4982,	0.4982,	0.4983,	0.4984,	0.4984,	0.4985,	0.4985,	0.4986,	0.4986],
[0.4987,	0.4987,	0.4987,	0.4988,	0.4988,	0.4989,	0.4989,	0.4989,	0.4990,	0.4990],
[0.4990,	0.4991,	0.4991,	0.4991,	0.4992,	0.4992,	0.4992,	0.4992,	0.4993,	0.4993],
[0.4993,	0.4993,	0.4994,	0.4994,	0.4994,	0.4994,	0.4994,	0.4995,	0.4995,	0.4995],
[0.4995,	0.4995,	0.4995,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4996,	0.4997],
[0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4997,	0.4998],
[0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998,	0.4998]]

# %%
# Definindo as funções de busca dos valores Z e T nas tabelas

def Z(Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    Grau_de_conf = abs(Grau_de_conf / 2.0)
    ri = 0
    rj = 0
    rdiff = 2
    for i in range(len(z_table)):
        for j in range(len(z_table[i])):
            diff = abs(z_table[i][j] - Grau_de_conf)
            if(diff < rdiff):
                ri = i
                rj = j
                rdiff = diff
    return round(ri * 0.1 + rj * 0.01, 2)

def T(N, Grau_de_conf):
    Grau_de_conf = Grau_de_conf/100
    N = N-1
    Grau_de_conf = round(0.5 - abs(Grau_de_conf / 2), 3)
    ri = -1
    rj =  -1
    
    for j in range(len(t_table[0])):
        if(Grau_de_conf == t_table[0][j]):
            rj = j
            break
    for i in range(len(t_table)):
        if(N == t_table[i][0]):
            ri = i
            break
    if(ri == -1 or rj == -1):
        print('ERROR!!!!!!!')
    return t_table[ri][rj]




# Definindo o tipo de região crítica de acordo com a hipótese alternativa.

import re

def Def_Tipo_Região(Significância, Ha):
    term = re.search('.*?_([<|>].?)_', Ha)

    if term.group(1) == "<":
        Unilateral_esquerda = True
        Bilateral = False
        Unilateral_direita = False
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == "<>":
        Unilateral_esquerda = False
        Bilateral = True
        Unilateral_direita = False
        return Unitaleral_esquerda, Bilateral, Unilateral_direita
    elif term.group(1) == ">":
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = True
        return Unilateral_esquerda, Bilateral, Unilateral_direita
    else:
        Unilateral_esquerda = False
        Bilateral = False
        Unilateral_direita = False
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return Unilateral_esquerda, Bilateral, Unilateral_direita
        
        
#Definindo valor de estudo do teste
def Def_Valor_estudo(Significância, Ha):
    Valor_estudado_temp = re.search('.*_(.*)', Ha)
    return float(Valor_estudado_temp.group(1))


#Definindo o valor passado para cálculo do valor crítico (z)
        
def Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa):

    if Unilateral_esquerda or Unilateral_direita:
        return (((1-Alfa)-(Alfa))*100)
    elif Bilateral:
        return (((1-Alfa)*100))
    else:
        print("ERROR: Operação de desigualdade não reconhecida em 'Ha'")
        return "ERROR"
    
    
#Definindo a função Normal padrão.
from scipy.integrate import quad
import numpy as np

def F_Normal_Padrao(z):
    constant = 1.0 / np.sqrt(2*np.pi)
    return(constant * np.exp((-z**2) / 2.0) )

# %%
#Realizando o teste de hipósteses para a Média.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Média_>=_2500"   #Hipótese nula (com igualdade)
Ha = "Média_<_2500"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 12 #casos
Média_amostral = 2500.9 #
Significância = 2.5 #% (alfa)
Variância = 1008.4
Desvio_populacional = False #O desvio conhecido é populacional?
Desvio_padrão = Variância**0.5 #Valor do desvio padrão populacional ou amostral




#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100


#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
if Desvio_populacional and N_amostras >= 30:
    Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))
else:
    Valor_crítico = T(N_amostras, Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Média_amostral-Valor_estudado)/(Desvio_padrão/(N_amostras**0.5)),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Desvio_populacional and N_amostras >= 10: # usando Z
    if Unilateral_esquerda:
        P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")
else: # usando T-Student
    if Unilateral_esquerda:
        P_valor, _ = quad(t.pdf, -np.inf, Estat_teste, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Unilateral_direita:
        P_valor, _ = quad(t.pdf, Estat_teste, np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        print("P valor: ",P_valor)
    elif Bilateral:
        P_valor, _ = quad(t.pdf, abs(Estat_teste), np.inf, args=(N_amostras-1))
        P_valor = round(P_valor, 6)
        P_valor = P_valor * 2
        print("P valor: ",P_valor)
    else:
        print("ERRO: Sem o tipo de teste para cálculo do valor P")


#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_médias_amostrais = Desvio_padrão/(N_amostras**0.5)
        E = round(Valor_crítico * Desvio_médias_amostrais,4)
        if Valor_estudado > Média_amostral-E and Valor_estudado < Média_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Média_amostral, E, Valor_estudado, Média_amostral-E, Média_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# H0:  Média_>=_2500
# Ha:  Média_<_2500
#
#
# Alfa:  0.025
# Valor crítico:  2.201
# Valor estudado:  2500.0
#
#
# Unilateral_esquerda:  True
# Bilateral:  False
# Unilateral_direita:  False
#
#
# Estatística de teste:  0.0982
# P valor:  0.53823
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 aceitada pois, Estatística de teste 0.0982 > Valor crítico -2.201
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 aceitada, pois P-valor 0.53823 >= Alfa 0.025
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.

# %%
#Realizando o teste de hipósteses para a Proporção.

import numpy as np
from scipy.stats import t



# Descrição das hipóteses:

H0 = "Proporção_<=_0.05"   #Hipótese nula (com igualdade)
Ha = "Proporção_>_0.05"   #Hipótese alternativa (sem igualdade)


#Variáveis do enunciado:

N_amostras = 100 #fumantes
Ocorrências = 10 #não fumaram
Prop_amostral = Ocorrências/N_amostras #proporção
Significância = 5 #% (alfa)



#Cálculos de variáveis secundárias
Unilateral_esquerda, Bilateral, Unilateral_direita = Def_Tipo_Região(Significância, Ha)
Valor_estudado = Def_Valor_estudo(Significância, Ha)
Alfa = Significância/100

#Verificação das suposições para a Proporção
if (N_amostras * Valor_estudado >= 5) and (N_amostras * (1-Valor_estudado) >= 5):
    print ("Suposições satifeitas (OK) para aproximação da distribuição por uma normal.")
    print("\n")
else:
    print ("Suposições não satifeitas (NOK) para aproximação da distribuição por uma normal.")
    print("\n")

#Cálculo do valor crítico com desvio populacional conhecido ou desconhecido
Valor_crítico = Z(Def_Valor_Crítico(Unilateral_esquerda, Bilateral, Unilateral_direita, Alfa))


print("H0: ",H0)
print("Ha: ",Ha)
print("\n")
print("Alfa: ",Alfa)
print("Valor crítico: ",Valor_crítico)
print("Valor estudado: ",Valor_estudado)
print("\n")
print("Unilateral_esquerda: ",Unilateral_esquerda)
print("Bilateral: ",Bilateral)
print("Unilateral_direita: ",Unilateral_direita)
print("\n")


#Cálculo da estatística de teste
Estat_teste = round((Prop_amostral-Valor_estudado)/(((Valor_estudado*(1-Valor_estudado))/N_amostras)**0.5),4)
print("Estatística de teste: ",Estat_teste)


#Cálculo o valor-p
if Unilateral_esquerda:
    P_valor, _ = quad(F_Normal_Padrao, -np.inf, Estat_teste)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Unilateral_direita:
    P_valor, _ = quad(F_Normal_Padrao, Estat_teste, np.inf)
    P_valor = round(P_valor, 6)
    print("P valor: ",P_valor)
elif Bilateral:
    P_valor, _ = quad(F_Normal_Padrao, abs(Estat_teste), np.inf)
    P_valor = round(P_valor, 6)
    P_valor = P_valor * 2
    print("P valor: ",P_valor)
else:
    print("ERRO: Sem o tipo de teste para cálculo do valor P")



#Verificação da hipótese nula de acordo com a estatística de teste:
print("\n")
print("Conclusão de acordo com a relação da estatística de teste e a região crítica:")

if Unilateral_esquerda:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} > Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
elif Unilateral_direita:
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))
elif Bilateral:
    if Estat_teste <= -Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} <= Valor crítico -{1}" .format(Estat_teste, Valor_crítico))
    if Estat_teste >= Valor_crítico:
        print("H0 rejeitada pois, Estatística de teste {0} >= Valor crítico {1}" .format(Estat_teste, Valor_crítico))
    else:
        print("H0 aceitada pois, Valor crítico -{1} < Estatística de teste {0} < Valor crítico {1}" .format(Estat_teste, Valor_crítico))


#Verificação da hipótese nula de acordo com o valor-p:       
print("\n")
print("Conclusão de acordo com a relação do valor-p e a significância:")

if P_valor < Alfa:
    print("H0 rejeitada, pois P-valor {0} < Alfa {1}" .format(P_valor, Alfa))
else:
    print("H0 aceitada, pois P-valor {0} >= Alfa {1}" .format(P_valor, Alfa))
    
    
#Verificação da hipótese nula de acordo com Intervalo de confiança (em caso de teste Bilateral):
print("\n")
print("Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:")

if Bilateral:
        Desvio_prop_amostrais = ((Prop_amostral * (1-Prop_amostral))/N_amostras)**0.5
        E = round(Valor_crítico * Desvio_prop_amostrais,4)
        if Valor_estudado > Prop_amostral-E and Valor_estudado < Prop_amostral+E:
            print("H0 aceitada, pois o Valor estudado {2} está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
        else:
            print("H0 rejeitada, pois o Valor estudado {2} não está contido no intervalo de confiança I.C = [{0}-{1} ; {0}+{1}] ou seja, de {3} a {4}" .format(Prop_amostral, E, Valor_estudado, Prop_amostral-E, Prop_amostral+E))
else:
    print("Teste não bilateral, portanto inviável análise através de I.C.")
# Out:
# Suposições satifeitas (OK) para aproximação da distribuição por uma normal.
#
#
# H0:  Proporção_<=_0.05
# Ha:  Proporção_>_0.05
#
#
# Alfa:  0.05
# Valor crítico:  1.64
# Valor estudado:  0.05
#
#
# Unilateral_esquerda:  False
# Bilateral:  False
# Unilateral_direita:  True
#
#
# Estatística de teste:  2.2942
# P valor:  0.01089
#
#
# Conclusão de acordo com a relação da estatística de teste e a região crítica:
# H0 rejeitada pois, Estatística de teste 2.2942 >= Valor crítico 1.64
#
#
# Conclusão de acordo com a relação do valor-p e a significância:
# H0 rejeitada, pois P-valor 0.01089 < Alfa 0.05
#
#
# Conclusão de acordo com a relação do valor estudado e o intervalo de confiança:
# Teste não bilateral, portanto inviável análise através de I.C.
